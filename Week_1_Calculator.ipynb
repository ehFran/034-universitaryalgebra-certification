# %% [markdown]
# # Proportions

# %%
# Set up a proportion (zero for the unknown value):
n1 = 1
d1 = 2
n2 = 4
d2 = 0

if n2 == 0:
  answer = d2 * n1 / d1
  print("n2 = ", answer)

if d2 == 0:
  answer = n2 * d1 / n1
  print("d2 = ", answer)

# %% [markdown]
# # Solve for X

# %%
# Solve for x:
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')
equation = input("Enter equation: 0 = ")

solution = solve(equation, x)
for s in solution:
  print("x = ", s)

# %% [markdown]
# # Factor

# %%
# Factor (equation to factor):
import sympy
from sympy import symbols

x, y = symbols('x y')
equation = x**3 - 2*x**2 - 5*x + 6

sympy.factor(equation)
# Out:
# (x - 3)*(x - 1)*(x + 2)

# %% [markdown]
# # Convert Decimal to Fraction and Percent

# %%
# Conver decimal to fractions and percent:
digits = input("Enter a decimal number to convert: ")
exponent = int(len(digits))-1
n = float(digits)
numerator = int(n * 10 ** exponent)
denominator = 10 ** exponent
percent = n * 100

# Output
print("The decimal is ", n)
print("The fraction is ", numerator, "/", denominator)
print("The percent is ", percent, "%")

# %% [markdown]
# # Solve for a Variable

# %%
# Solve for a variable:
from sympy import *
import math

# Identify all variable
var('a b c d x y')

#Left and right side of the equal sign
left = 0
right = a*x*2 + b*x + c

# Variable to solve for
variable = x

# Sympy equation left = right
equation_1 = Eq(left, right)

# Sympy solve for that variable
solution = solve(equation_1, variable)

# Show factored results
for s in solution:
  print(variable, " = ", s)
# Out:
# x  =  -c/(2*a + b)
